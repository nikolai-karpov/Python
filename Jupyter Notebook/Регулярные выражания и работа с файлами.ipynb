# %% [markdown]
# # Регулярные выражания и работа с файлами

# %% [markdown]
# Булыгин Олег:
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Telegram](https://t.me/obulygin91)
# * [facebook](fb.com/obulygin91)
# * [Vk](vk.com/obulygin91)
# * email: obulygin91@ya.ru
#
# [Сообщество по Python](https://yandex.ru/q/loves/pythontalk/) на Кью
# [Сообщество по Data Science и анализу данных](https://yandex.ru/q/loves/datatalk/) на Кью

# %% [markdown]
# ## Регулярные выражения
# Регулярные выражения (Regular Expressions, regex) – это строки, содержащие совокупность обычных символов и специальных метасимволов, которые описывают определенный шаблон.
#
# Эти шаблоны, к примеру, можно использовать для того, чтобы:
# - находить и заменять что-то в текстовых данных;
# - валидировать строковые поля.
#
# Шаблоны могут быть настолько сложными, что другими способами определить их будет крайне трудно.
#
# Одна из особенностей регулярных выражений в их универсальности, стоит вам выучить синтаксис, и вы сможете применять их в любом (почти) языке программирования (JavaScript, Java, VB, C #, C / C++, Python, Perl, Ruby, Delphi, R, Tcl, и многих других). Небольшие отличия касаются только наиболее продвинутых функций и версий синтаксиса, поддерживаемых движком.

# %% [markdown]
# ![3V0WTsL8gaU.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# >Если у вас есть проблема, и вы собираетесь ее решать с помощью регулярных выражений, тогда у вас будет уже две проблемы.
#
# <cite>Шутка из интернетов (не шутка)</cite>. [Вот так](https://www.ex-parrot.com/~pdw/Mail-RFC822-Address.html) может выглядеть страшная регулярка.

# %% [markdown]
# Основы синтаксиса регулярных выражений

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td width="20%"><b>Последовательность</b></td>
# <td width="60%"><b>Описание</b></td>
# <td width="20%"><b>Аналог с []</b></td>
# </tr>
# <tr>
# <td>\d</td>
# <td>Любая цифра</td>
# <td>[0-9]</td>
# </tr>
# <tr>
# <td>\D</td>
# <td>Всё что угодно, кроме цифры</td>
# <td>[^0-9]</td>
# </tr>
# <tr>
# <td>\s</td>
# <td>Любой пробельный символ</td>
# <td>[ \t\n\r\f\v]</td>
# </tr>
# <tr>
# <td>\S</td>
# <td>Любой непробельный символ</td>
# <td>[^ \t\n\r\f\v]</td>
# </tr>
# <tr>
# <td>\w</td>
# <td>Любая буква, цифра, знак подчёркивания</td>
# <td>[a-zA-Z0-9_]</td>
# </tr>
# <tr>
# <td>\W</td>
# <td>Всё что угодно, кроме букв, цифр и знака подчёркивания</td>
# <td>[^a-zA-Z0-9_]</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td width="20%"><b>Символ</b></td>
# <td width="80%"><b>Пояснение</b></td>
# </tr>
#
# <tr>
# <td>.</td>
# <td>Любой символ</td>
# </tr>
#
# <tr>
# <td>*</td>
# <td>Ноль и более&nbsp;совпадений с выражением, заданным в качестве образца&nbsp;</td>
# </tr>
#
# <tr>
# <td>+</td>
# <td>Одно и более&nbsp;совпадений с выражением, заданным в качестве образца&nbsp;</td>
# </tr>
#
# <tr>
# <td>?</td>
# <td>Ноль или одно&nbsp;совпадение с выражением, заданным в качестве образца&nbsp;</td>
# </tr>
#
# <tr>
# <td>[ ]</td>
# <td>Совпадение с любым из символов, заключённым в скобки</td>
# </tr>
#
# <tr>
# <td>[^ ]</td>
# <td>Совпадение с любым из символов, отсутствующим в скобках</td>
# </tr>
#
# <tr>
# <td>\</td>
# <td>Экранирует специальные символы (т.е. позволяет использовать символы типа '.', '*', '?' в роли обычных элементов строки)</td>
# </tr>
#
# <tr>
# <td>^ и $</td>
# <td>Начало и конец строки соответственно</td>
# </tr>
#
# <tr>
# <td>a|b</td>
# <td>Соответствует a или b</td>
# </tr>
#
# </tbody>
# </table>

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td width="20%"><b>Квантификатор</b></td>
# <td width="80%"><b>Пояснение</b></td>
# </tr>
#
# <tr>
# <td>{n,m}</td>
# <td>повторений предыдущего символа или группы символов может быть от n до m включительно</td>
# </tr>
#
# <tr>
# <td>{n,}</td>
# <td>n и более повторений предыдущего символа или группы символов</td>
# </tr>
#
# <tr>
# <td>{,m}</td>
# <td>не более m повторений предыдущего символа или группы символов</td>
# </tr>
#
# <tr>
# <td>{n}</td>
# <td>ровно n повторений предыдущего символа или группы символов</td>
# </tr>
#
# </tbody>
# </table>

# %%
# импортируем модуль для работы с регулярками в python
import re

# %% [markdown]
# **raw string** – подавляет значение escape-последовательностей, обозначается префиксом r перед обычной строкой.
# Настоятельно рекомендуется использовать всегда при работе с регулярными выражениями для избежания проблем.

# %% [markdown]
# Функция `re.findall(pattern, string)` – ищет во всем тексте, возвращает список всех найденных совпадений

# %%
# найдем идентификаторы пользователей в тексте
msg = 'В розыгрыше победили: id1234563, id4653, id461'

# %%
print(re.findall(r'id\d+', msg))
# Out:
# []

# %% [markdown]
# **Практика**. Найдем хэштеги в твите

# %%
tweet = 'когда #эпидемия, то обязательно #оставайсядома'

# %%
print(re.findall(r'#\w+', tweet))
# Out:
# ['#эпидемия', '#оставайсядома']

# %%
# вытащим номера телефонов и текста
phone_numbers = 'Мария: 8-943-342-23-32 Александр: 8-323-432-23-67'

phone_pattern = r'\d-\d{3}-\d{3}-\d{2}-\d{2}'
print(re.findall(phone_pattern, phone_numbers))
# Out:
# ['8-943-342-23-32', '8-323-432-23-67']

# %%
# [] - найдем слово во всем склонениях

text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""
pattern = 'регулярн[а-я]+ выражен[а-я]+'
print(re.findall(pattern, text))
# Out:
# ['регулярные выражения', 'регулярное выражение', 'регулярных выражений']

# %% [markdown]
# Функция `re.sub(pattern, repl, string)` – ищет шаблон в строке и заменяет его на указанную подстроку.

# %% [markdown]
# Простой способ удалить все знаки препинания

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""

print(re.sub(r'[^\w\s]', '', text))
# Out:
# Что такое регулярные выражения и как их использовать
# Говоря простым языком регулярное выражение  это последовательность символов используемая для поиска и замены текста в строке или файле Как уже было упомянуто
# их поддерживает множество языков общего назначения Python Perl R
# Так что изучение регулярных выражений рано или поздно пригодится

# %% [markdown]
# **Практика**. Произведем замену "Регулярные выражения" во всех формах на "regex"

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""

# %%
print(re.sub(r'регулярн[а-я]+ выражен[а-я]+', 'regex', text))
# Out:
# Что такое regex и как их использовать?
# Говоря простым языком, regex — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
# их поддерживает множество языков общего назначения: Python, Perl, R.
# Так что изучение regex рано или поздно пригодится.

# %% [markdown]
# Исключим лишние пробельные символы из начала и конца строки

# %%
text = '    Тут текст в который попали пробельные символы в начале и в конце, от которых нужно избавиться   ' 

print(re.sub(r'^\s+|\s+$', '', text))
# Out:
# Тут текст в который попали пробельные символы в начале и в конце, от которых нужно избавиться

# %% [markdown]
# Зацензурируем слова

# %%
text = "Некоторые обычные слова подозрительны: хор, хук, хек." 
print(re.sub(r'\b[хХ]\w{2}\b', 'censored', text))
# Out:
# Некоторые обычные слова подозрительны: censored, censored, censored.

# %% [markdown]
# Функция `re.split(pattern, string)` – разделяет строку по заданному шаблону

# %%
columns = 'Столбец1,Столбец2;Столбец3, Столбец4; Столбец5'
print(re.split(r'[,;]\s?', columns))
# Out:
# ['Столбец1', 'Столбец2', 'Столбец3', 'Столбец4', 'Столбец5']

# %% [markdown]
# Функция `re.match(pattern, string)` – ищет по заданному шаблону в начале строки. Возвращает match-объект

# %% [markdown]
# Как нам найти все изображения в потенциально огромном списке файлов буквально в пару строк кода? За изображения будем считать файлы с расширениями jpg, png и gif.
#
# Для каждого подходящего файла будем выводить фразу
# `Изображение найдено: название файла`,
# а если файл не подходит, то `"Название файла" не является изображением`.

# %%
file_name_list = ['my.profile', 'conspect.doc', 'my_photo.jpg', 'error-jpg', 'img0912.png', 'index.html', 'favicon.gif', 'img_copy.jpg.tmp']

# %%
for file in file_name_list:
    pattern = r'\w+\.(jpg|png|gif)$'
    if re.match(pattern, file):
        print(f'Изображение найдено: {file}')
    else:
        print(f'{file} не является изображением')
# Out:
# my.profile не является изображением
# conspect.doc не является изображением
# Изображение найдено: my_photo.jpg
# error-jpg не является изображением
# Изображение найдено: img0912.png
# index.html не является изображением
# Изображение найдено: favicon.gif
# img_copy.jpg.tmp не является изображением

# %% [markdown]
# Часть шаблона можно заключить в скобки (...). Это называется «скобочная группа».
# Это позволяет:
# - поместить часть шаблона в отдельную структуру (группу);
# - если установить квантификатор после скобок, то он будет применяться ко всему содержимому скобки, а не к одному символу.
#
# При наличии подгрупп в шаблоне можно ссылаться на них через их порядковый номер при помощи \1, \2, \3, …

# %% [markdown]
# Выделим группы символов из посадочного талона, где:
# - первые 2 символа - это авиакомпания;
# - 4 следующие символа - номер рейса;
# - 3 следующих символа - аэропорт отправления;
# - 3 следюущих - аэропорт прибытия;
# - оставшиеся - дата рейса.
#
# Предполагаем, что все буквы всегда в верхнем регистре

# %%
flight = """
Boarding pass: LA4214 AER-CDB 06NOV
Boarding pass: LA4215 AER-CDB 07NOV
"""

# %% [markdown]
# Функция `re.search(pattern, repl, string)` – ищет шаблон по всей строке, но только первое вхождение. Возвращает match-объект

# %%
regex_flight = r'([A-Z]{2})(\d{4})\s([A-Z]{3})-([A-Z]{3})\s(\d{2}[A-Z]{3})'

flight_match_result = re.search(regex_flight, flight)
print(flight_match_result.group())
# Out:
# LA4214 AER-CDB 06NOV

# %% [markdown]
# А как отработает findall?

# %%
regex_flight = r'([A-Z]{2})(\d{4})\s([A-Z]{3})-([A-Z]{3})\s(\d{2}[A-Z]{3})'

flight_match_result = re.findall(regex_flight, flight)
print(flight_match_result)
# Out:
# [('LA', '4214', 'AER', 'CDB', '06NOV'), ('LA', '4215', 'AER', 'CDB', '07NOV')]

# %% [markdown]
# Переведем даты к другому формату при помощи групп

# %%
date = 'some text 08/30/1991 some text'

# %%
print(re.sub(r'(\d\d)/(\d\d)/(\d{4})', r'\2.\1.\3', date))
# Out:
# some text 30.08.1991 some text

# %% [markdown]
# Удалим все последовательные повторы слов из текста

# %%
some_string = 'Напишите функцию функцию, которая будет будет будет будет удалять все все все все последовательные повторы слов из из из из заданной строки строки при помощи регулярных выражений.'

# %%
print(re.sub(r"(\w+)(\s\1)+", r"\1", some_string))
# Out:
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.

# %% [markdown]
# Флаги в реглярных выражениях

# %%
text = """Что такое регулярные выражения и как их использовать? 
Говоря простым языком, регулярное выражение — это последовательность символов, используемая для поиска и замены текста в строке или файле. Как уже было упомянуто,
их поддерживает множество языков общего назначения: Python, Perl, R.
Так что изучение регулярных выражений рано или поздно пригодится."""

# %%
print(re.findall(r'[a-z]+', text)) 
print(re.findall(r'[a-z]+', text, flags=re.IGNORECASE))
# Out:
# ['Python', 'Perl', 'R']
# ['Python', 'Perl', 'R']

# %%
print(re.findall(r'^\w+', text)) 
print(re.findall(r'^\w+', text, flags=re.MULTILINE))
# Out:
# ['Что']
# ['Что', 'Говоря', 'их', 'Так']

# %% [markdown]
# Позиционная проверка (lookaround) – используется при поиске шаблона, которому обязательно предшествует или следует другой шаблон.
#
# `?=` - Положительный lookahead (ищет шаблон, если он находится до указанной группы)
# `?!` - Отрицательный lookahead (ищет шаблон, если он не находится до указанной группы)
# `?<=` - Положительный lookbehind (ищет шаблон, если он находится после указанной группы)
# `?<!` - Отрицательный lookbehind (ищет шаблон, если он не находится после указанной группы)

# %%
# lookaround. Достанем имена только загруженных файлов
report = 'файл 11.txt загружен, файл 22.txt загружен, файл 33.txt ошибка'
# find_downloaded = r'\d+\.txt(?=\sзагружен)'
files_error = r'\d+\.txt(?!\sзагружен)'
# print(re.findall(find_downloaded, report))
print(re.findall(files_error, report))
# Out:
# ['33.txt']

# %% [markdown]
# **Практика**. Произведем замену "Регулярные выражения" во всех формах на "regex"

# %%
prices = 'RUB4.44, RUB10.88, EUR0.99, RUB99.99'

# %%
regex_pattern = r'(?<=RUB)\d*\.\d{2}'

print(re.findall(regex_pattern, prices))
# Out:
# ['4.44', '10.88', '99.99']

# %%
list_prices = r'?<=RUB)\d*\.\d{2}'
print(re.findall(list_prices, prices))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-51-de8123834beb> in <module>()
#       1 list_prices = r'?<=RUB)\d*\.\d{2}'
# ----> 2 print(re.findall(list_prices, prices))
#
# /usr/lib/python3.7/re.py in findall(pattern, string, flags)
#     223
#     224     Empty matches are included in the result."""
# --> 225     return _compile(pattern, flags).findall(string)
#     226
#     227 def finditer(pattern, string, flags=0):
#
# /usr/lib/python3.7/re.py in _compile(pattern, flags)
#     286     if not sre_compile.isstring(pattern):
#     287         raise TypeError("first argument must be string or compiled pattern")
# --> 288     p = sre_compile.compile(pattern, flags)
#     289     if not (flags & DEBUG):
#     290         if len(_cache) >= _MAXCACHE:
#
# /usr/lib/python3.7/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# /usr/lib/python3.7/sre_parse.py in parse(str, flags, pattern)
#     922
#     923     try:
# --> 924         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     925     except Verbose:
#     926         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /usr/lib/python3.7/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     418     while True:
#     419         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 420                            not nested and not items))
#     421         if not sourcematch("|"):
#     422             break
#
# /usr/lib/python3.7/sre_parse.py in _parse(source, state, verbose, nested, first)
#     643             if not item or item[0][0] is AT:
#     644                 raise source.error("nothing to repeat",
# --> 645                                    source.tell() - here + len(this))
#     646             if item[0][0] in _REPEATCODES:
#     647                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 0

# %% [markdown]
# [Документация по регулярным выражениям](https://docs.python.org/3/library/re.html)
# [Тестер регулярных выражений](https://regex101.com/)
# https://regexcrossword.com/howtoplay

# %% [markdown]
# ## Чтение неструктурированных файлов

# %% [markdown]
# Файл — именованная область данных на носителе информации.

# %% [markdown]
# Python поддерживает множество различных типов файлов, но условно их можно разделить на два виде: текстовые и бинарные.
#
# Текстовые файлы - это к примеру файлы с расширением csv, txt, html, в общем любые файлы, которые сохраняют информацию в текстовом виде.
#
# Бинарные файлы - это изображения, аудио и видеофайлы и т.д. В зависимости от типа файла работа с ним может немного отличаться.

# %% [markdown]
# <code> with open(file, mode) as file_obj:
#     инструкции </code>
#
# Эта конструкция определяет для открытого файла переменную file_obj и выполняет набор инструкций. После их выполнения файл автоматически закрывается. Даже если при выполнении инструкций в блоке with возникнут какие-либо исключения, то файл все равно закрывается.

# %% [markdown]
# Запись в файл

# %%
# запись в файл (аргумент w)
with open('data.txt', 'w') as f:
    f.write('Привет, мир!')

# %%
# попытка записать данные в файл
# по умолчанию используется режим чтения
with open('data.txt') as f:
    f.write('Привет, мир!')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-53-42626920e61c> in <module>()
#       2 # по умолчанию используется режим чтения
#       3 with open('data.txt') as f:
# ----> 4     f.write('Привет, мир!')
#
# UnsupportedOperation: not writable

# %%
# попытка записать две строки но в разных сессиях в файл, который открыт на запись
# при таком режиме всегда происходит перезапись содержимого

with open('data.txt', 'w') as f:
    f.write('Первая строка!')
with open('data.txt', 'w') as f:
    f.write('Вторая строка!')

# %%
#  дозаписывать в файл нужно при помощи аргумента а
with open('data.txt', 'a') as f:
    f.write('Первая строка! \n')
with open('data.txt', 'a') as f:
    f.write('Вторая строка! \n')

# %% [markdown]
# Чтение файла

# %%
# попытка прочитать в файл который открыт на запись
with open('data.txt', 'w') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-59-150bcc190e33> in <module>()
#       1 # попытка прочитать в файл который открыт на запись
#       2 with open('data.txt', 'w') as f:
# ----> 3     print(f.read())
#
# UnsupportedOperation: not readable

# %%
# попытка прочитать в файл который открыт на запись И чтение
with open('data.txt', 'wr') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-46090f0f4613> in <module>()
#       1 # попытка прочитать в файл который открыт на запись И чтение
# ----> 2 with open('data.txt', 'wr') as f:
#       3     print(f.read())
#
# ValueError: must have exactly one of create/read/write/append mode

# %%
with open('data.txt', 'w') as f:
    pass

# %%
# Читаем файл целиком
with open('data.txt') as f:
    data = f.read()
    # print(type(data))
    print(data)
# Out:
# Первая строка!
# Вторая строка!

# %%
# Читаем по одной строке
with open('data.txt') as f:
    print(f.readline().strip())
    print(f.readline().strip())
    print(f.readline().strip())
    print(f.readline() == '')
    print(f.readline() is None)
# Out:
# Первая строка!
# Вторая строка!
#
# True
# False

# %%
# Читаем все строки сразу, запишутся в список
with open('data.txt') as f:
    lines = f.readlines()
    print(type(lines))
    print(len(lines))
    print(lines[1])
# Out:
# <class 'list'>
# 2
# Вторая строка!

# %%
# Читаем строки в цикле
with open('data.txt') as file:
    for line in file:
        print(line.strip())
# Out:
# Первая строка!
# Вторая строка!

# %% [markdown]
# Пример

# %%
# имя файла
FILENAME = "messages.txt"
# определяем пустой список
messages = []
 
for i in range(4):
    message = input(f"Введите строку {i+1}: ")
    messages.append(message + "\n")

# запись списка в файл
with open(FILENAME, "a") as f:
    for message in messages:
        f.write(message)

# считываем сообщения из файла
print("Считанные сообщения")
with open(FILENAME, "r") as f:
    for message in f:
        print(message, end="")
# Out:
# Введите строку 1: dfh
# Введите строку 2: dfh
# Введите строку 3: 56
# Введите строку 4: fh
# Считанные сообщения
#
# dfh
# dfh
# 56
# fh

# %% [markdown]
# Для того чтобы работать с файлами в Python полезно понимать принципы работы path
# Рабочая библиотека [os](https://python-scripts.com/import-os-example)

# %%
import os

# %%
# Получение пути от корня файловой системы к текущему каталогу
print("==> ", os.getcwd())
# Out:
# ==>  /content

# %%
# Построение пути к файлу (платформоспецифично)
file_path = os.path.join(os.getcwd(), 'data.txt')
print("==> ", file_path)
# Out:
# ==>  /content/data.txt

# %%
with open(file_path, 'r') as f:
    print(f.read())
# Out:
# Первая строка!
# Вторая строка!

# %%
# можем посмотреть все файлы в текущей директории
os.listdir()
# Out:
# ['.config',
#  'recipes.txt',
#  'data.txt',
#  'messages.txt',
#  'hello.txt',
#  'sample_data']

# %%
# например так можно зафиксировать все файлы определенного расширения
[i for i in os.listdir() if i.endswith('txt')]
# Out:
# ['recipes.txt', 'data.txt', 'messages.txt', 'hello.txt']

# %% [markdown]
# Для компьютера текст (как и любые другие данные) — это набор байтов.
# Мы (люди) хотим работать со строками, байты нам читать сложно. Кодировка — это способ сопоставления байтов символам.
# По умолчанию в Python при работе с файлами используется utf-8. Для изменения кодировки в функции open есть параметр encoding.

# %%
#Записываем файл в кодировке utf-8 (linux)

with open('utf.txt', 'w', encoding='utf-8') as f:
    f.write('Привет, мир!')

# %%
# Записываем файл в кодировке cp1251 (windows)

with open('cp.txt', 'w', encoding='cp1251') as f:
    f.write('Привет, мир!')

# %%
# Читаем файлы в байтах чтобы показать разницу в кодировках
with open('cp.txt', 'rb') as f:
    print('cp1251 ==> ', f.read())
with open('utf.txt', 'rb') as f:
    print('utf-8 ==> ', f.read())
# Out:
# cp1251 ==>  b'\xcf\xf0\xe8\xe2\xe5\xf2, \xec\xe8\xf0!'
# utf-8 ==>  b'\xd0\x9f\xd1\x80\xd0\xb8\xd0\xb2\xd0\xb5\xd1\x82, \xd0\xbc\xd0\xb8\xd1\x80!'

# %%
# Чение файла с указанием неверной кодировки

with open('cp.txt', 'r') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-87-bb74afd77ac1> in <module>()
#       2
#       3 with open('cp.txt', 'r') as f:
# ----> 4     print(f.read())
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcf in position 0: invalid continuation byte

# %%
# Чтение файла с указанием верной кодировки

with open('cp.txt', 'r', encoding='cp1251') as f:
    print(f.read())
# Out:
# Привет, мир!

# %% [markdown]
# Модуль [chardet](https://pypi.org/project/chardet/) может помочь в автоматическом определении кодировки

# %% [markdown]
# Необходимо написать программу для кулинарной книги.
#
# Список рецептов хранится в отдельном файле.
#
# На его основе должен получится следующий словарь
#
# ```
# cook_book = {
#   'Омлет': [
#     {'ingredient_name': 'Яйцо', 'quantity': 2, 'measure': 'шт.'},
#     {'ingredient_name': 'Молоко', 'quantity': 100, 'measure': 'мл'},
#     {'ingredient_name': 'Помидор', 'quantity': 2, 'measure': 'шт'}
#     ],
#   'Утка по-пекински': [
#     {'ingredient_name': 'Утка', 'quantity': 1, 'measure': 'шт'},
#     {'ingredient_name': 'Вода', 'quantity': 2, 'measure': 'л'},
#     {'ingredient_name': 'Мед', 'quantity': 3, 'measure': 'ст.л'},
#     {'ingredient_name': 'Соевый соус', 'quantity': 60, 'measure': 'мл'}
#     ],
#   'Запеченный картофель': [
#     {'ingredient_name': 'Картофель', 'quantity': 1, 'measure': 'кг'},
#     {'ingredient_name': 'Чеснок', 'quantity': 3, 'measure': 'зубч'},
#     {'ingredient_name': 'Сыр гауда', 'quantity': 100, 'measure': 'г'},
#     ]
# ```

# %%
from pprint import pprint

def get_cookbook_from_file(file_name):
    path = os.path.join(os.getcwd(), file_name)
    cook_book = {}

    with open(path, encoding='utf-8') as file:
        for dish in file:
            dish_name = dish.strip()
            counter = int(file.readline().strip())

            temp_data = []

            for item in range(counter):
                ingr_name, quantity, measure = file.readline().split('|')
                temp_data.append({'ingr_name': ingr_name.strip(), 'q':quantity.strip(), 'm':measure.strip()})
            cook_book[dish_name] = temp_data
            file.readline()

    return cook_book

pprint(get_cookbook_from_file('recipes.txt'))
# Out:
# {'Запеченный картофель': [{'ingr_name': 'Картофель', 'm': 'кг', 'q': '1'},
#                           {'ingr_name': 'Чеснок', 'm': 'зубч', 'q': '3'},
#                           {'ingr_name': 'Сыр гауда', 'm': 'г', 'q': '100'}],
#  'Омлет': [{'ingr_name': 'Яйцо', 'm': 'шт', 'q': '2'},
#            {'ingr_name': 'Молоко', 'm': 'мл', 'q': '100'},
#            {'ingr_name': 'Помидор', 'm': 'шт', 'q': '2'}],
#  'Утка по-пекински': [{'ingr_name': 'Утка', 'm': 'шт', 'q': '1'},
#                       {'ingr_name': 'Вода', 'm': 'л', 'q': '2'},
#                       {'ingr_name': 'Мед', 'm': 'ст.л', 'q': '3'},
#                       {'ingr_name': 'Соевый соус', 'm': 'мл', 'q': '60'}],
#  'Фахитос': [{'ingr_name': 'Говядина', 'm': 'г', 'q': '500'},
#              {'ingr_name': 'Перец сладкий', 'm': 'шт', 'q': '1'},
#              {'ingr_name': 'Лаваш', 'm': 'шт', 'q': '2'},
#              {'ingr_name': 'Винный уксус', 'm': 'ст.л', 'q': '1'},
#              {'ingr_name': 'Помидор', 'm': 'шт', 'q': '2'}]}

# %% [markdown]
# # Спасибо за внимание! Буду рад ответить на ваши вопросы
# Форма ОС: https://forms.gle/y8xaFwJqtbFSjUeG8
